# %%
pip install pyTelegramBotAPI

# %%
# Import necessary libraries
import telebot
import random

# Replace 'YOUR_BOT_TOKEN' with your bot's token
bot = telebot.TeleBot('6648798907:AAG2sN5padswrU806UTUyYixYIU7KjltA5U')

# Command to start the bot
@bot.message_handler(commands=['start'])
def handle_start(message):
    start_text = "Welcome to the GATE Examination Bot for Developers!\n\n"
    start_text += "I'm here to assist you in your GATE preparation journey. Type /help for instructions."
    bot.send_message(message.chat.id, start_text)

# Command to provide help
@bot.message_handler(commands=['help'])
def handle_help(message):
    help_text = "You can use the following commands to supercharge your GATE preparation:\n\n"
    help_text += "/syllabus - View the GATE examination syllabus\n"
    help_text += "/studyplan - Get a study plan for GATE preparation\n"
    help_text += "/resources - Access GATE study materials and resources\n"
    help_text += "/mocktests - Practice with GATE mock tests\n"
    help_text += "/subject1 - Engineering Mathematics\n"
    help_text += "/subject2 - Digital Logics\n"
    help_text += "/subject3 - Computer Organisation and Architecture\n"
    help_text += "/subject4 - Programming and Data Structure\n"
    help_text += "/subject5 - Algorithms\n"
    help_text += "/subject6 - Theory of Computations\n"
    help_text += "/subject7 - Compiler Design\n"
    help_text += "/subject8 - Operating System\n"
    help_text += "/subject9 - Databases\n"
    help_text += "/subject10 - Computer Networks\n"
    help_text += "/welcome - Welcome message\n"
    help_text += "/goodluck - Wish the user good luck\n"
    help_text += "/thanks - Express gratitude\n"
    help_text += "/randomtip - Get a random study tip\n"
    help_text += "/motivate - Get a motivational quote\n"
    help_text += "/joke - Need a study break? Get a joke\n"
    bot.send_message(message.chat.id, help_text)

# Command to view the GATE examination syllabus
@bot.message_handler(commands=['syllabus'])
def handle_syllabus(message):
    syllabus_text = "GATE Examination Syllabus:\n\n"
    syllabus_text += "https://gate.iitkgp.ac.in/gate_syllabus.html"
    bot.send_message(message.chat.id, syllabus_text)

# Command to provide a study plan
@bot.message_handler(commands=['studyplan'])
def handle_study_plan(message):
    study_plan_text = "Study Plan for GATE Preparation:\n\n"
    study_plan_text += "1. Understand the GATE syllabus and exam pattern.\n"
    study_plan_text += "2. Set clear goals and create a study schedule.\n"
    study_plan_text += "3. Use GATE study materials and recommended textbooks.\n"
    bot.send_message(message.chat.id, study_plan_text)

# Command to access GATE study resources
@bot.message_handler(commands=['resources'])
def handle_resources(message):
    resources_text = "GATE Study Resources:\n\n"
    resources_text += "1. [Official GATE Website](https://gate.iitkgp.ac.in/)\n"
    resources_text += "2. [NPTEL Online Courses](https://nptel.ac.in/)\n"
    resources_text += "3. [GATE Overflow](https://gateoverflow.in/)\n"
    resources_text += "4. [GATE Academy YouTube Tutorials](https://www.youtube.com/user/gateacademy1)\n"
    resources_text += "5. [Ravindrababu Ravula YouTube Lectures](https://www.youtube.com/user/ravula)\n"
    resources_text += "6. [Unacademy GATE - The Complete Course](https://www.youtube.com/c/UnacademyGATE)\n"
    resources_text += "7. [Learn GATE Free YouTube Channel](https://www.youtube.com/c/LearnGATEFree)\n"
    resources_text += "8. [GATEFORUM Educational Services YouTube Channel](https://www.youtube.com/c/GATEFORUMEduservices)\n"
    bot.send_message(message.chat.id, resources_text, parse_mode="Markdown")

# Command to practice with GATE mock tests
@bot.message_handler(commands=['mocktests'])
def handle_mock_tests(message):
    bot.send_message(message.chat.id, "You can practice with GATE mock tests on various educational websites and platforms.")

# YouTube links for subjects (Replace with your actual links)
@bot.message_handler(commands=['subject1'])
def handle_subject1(message):
    subject1_text = "Engineering Mathematics - [Link to Subject 1 Materials](https://www.youtube.com/watch?v=bfAYYLamQPQ&list=PLC36xJgs4dxEYmhzVBW7nBdftFZ4xmiF1)"
    bot.send_message(message.chat.id, subject1_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject2'])
def handle_subject2(message):
    subject2_text = "Digital Logics - [Link to Subject 2 Materials](https://www.youtube.com/watch?v=elqrlY0L0ds&list=PLC36xJgs4dxEErKQZ7xFxat8oh4OepU34)"
    bot.send_message(message.chat.id, subject2_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject3'])
def handle_subject3(message):
    subject3_text = "Computer Organisation and Architecture - [Link to Subject 3 Materials](https://www.youtube.com/watch?v=zMkye9iaWB4&list=PLG9aCp4uE-s3WzvFW1nI-7hHWNC8s2RdI)"
    bot.send_message(message.chat.id, subject3_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject4'])
def handle_subject4(message):
    subject4_text = "Programming and Data Structure - [Link to Subject 4 Materials](https://www.youtube.com/watch?v=LbfMRnOhJGs&list=PLG9aCp4uE-s0j5Er7XarVwb2Vl-s0z-OJ)"
    bot.send_message(message.chat.id, subject4_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject5'])
def handle_subject5(message):
    subject5_text = "Algorithms - [Link to Subject 5 Materials](https://www.youtube.com/watch?v=LOsOjD3v6Cg&list=PLir19lgiavA2h95ln1UUwPoZkt9ueSbhQ)"
    bot.send_message(message.chat.id, subject5_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject6'])
def handle_subject6(message):
    subject6_text = "Theory of Computations - [Link to Subject 6 Materials](https://www.youtube.com/watch?v=XslI8h7cGDs&list=PLxCzCOWd7aiFM9Lj5G9G_76adtyb4ef7i)"
    bot.send_message(message.chat.id, subject6_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject7'])
def handle_subject7(message):
    subject7_text = "Compiler Design - [Link to Subject 7 Materials](https://www.youtube.com/watch?v=FWBIYCb5v8g&list=PLynLXReWAxdGn85HptGs0Qz_esWIItC5s)"
    bot.send_message(message.chat.id, subject7_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject8'])
def handle_subject8(message):
    subject8_text = "Operating System - [Link to Subject 8 Materials](https://www.youtube.com/watch?v=By6lWjiPpVI&list=PLG9aCp4uE-s17rFjWM8KchGlffXgOzzVP)"
    bot.send_message(message.chat.id, subject8_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject9'])
def handle_subject9(message):
    subject9_text = "Databases - [Link to Subject 9 Materials](https://www.youtube.com/watch?v=khKoJUpcXUE&list=PLG9aCp4uE-s0bu-I8fgDXXhVLO4qVROGy)"
    bot.send_message(message.chat.id, subject9_text, parse_mode="Markdown")

@bot.message_handler(commands=['subject10'])
def handle_subject10(message):
    subject10_text = "Computer Networks - [Link to Subject 10 Materials](https://www.youtube.com/watch?v=pGWxdTJPjKE&list=PL3eEXnCBViH-hlNCNwdfV7VrEcTquANGa)"
    bot.send_message(message.chat.id, subject10_text, parse_mode="Markdown")

# Additional commands
@bot.message_handler(commands=['welcome'])
def handle_welcome(message):
    welcome_text = "Welcome to the GATE Examination Bot for Developers!\n"
    welcome_text += "I'm here to assist you in your GATE preparation journey. If you have any questions, feel free to ask!"
    bot.send_message(message.chat.id, welcome_text)

@bot.message_handler(commands=['goodluck'])
def handle_good_luck(message):
    good_luck_text = "Good luck with your GATE preparation! You've got this! If you need motivation, just type /motivate."
    bot.send_message(message.chat.id, good_luck_text)

@bot.message_handler(commands=['thanks'])
def handle_thanks(message):
    thanks_text = "Thanks for using this bot. If you have any feedback or suggestions, let me know. Happy studying!"
    bot.send_message(message.chat.id, thanks_text)

# Command to provide a random study tip
@bot.message_handler(commands=['randomtip'])
def handle_random_tip(message):
    tips = [
        "Take regular breaks to keep your mind fresh and focused.",
        "Use flashcards to memorize key concepts and formulas.",
        "Join study groups to discuss topics with peers.",
        "Teach the concepts to someone else to reinforce your understanding.",
        "Practice previous year's GATE questions to get a feel for the exam pattern."
    ]
    random_tip = random.choice(tips)
    bot.send_message(message.chat.id, f"Study Tip: {random_tip}")

# Command to provide a motivational quote
@bot.message_handler(commands=['motivate'])
def handle_motivate(message):
    quotes = [
        "Success is not final, failure is not fatal: It is the courage to continue that counts. - Winston Churchill",
        "Don't watch the clock; do what it does. Keep going. - Sam Levenson",
        "Believe you can and you're halfway there. - Theodore Roosevelt",
        "The only way to do great work is to love what you do. - Steve Jobs",
        "It always seems impossible until it's done. - Nelson Mandela"
    ]
    motivational_quote = random.choice(quotes)
    bot.send_message(message.chat.id, f"Motivational Quote: {motivational_quote}")

# Command to provide a joke
@bot.message_handler(commands=['joke'])
def handle_joke(message):
    jokes = [
        "Why did the computer keep its drink on the windowsill? Because it wanted a cold drink.",
        "Why did the programmer quit his job? Because he didn't get arrays.",
        "Why do Java developers wear glasses? Because they can't C#!",
        "Why was the math book sad? Because it had too many problems.",
        "Why did the scarecrow become a successful computer scientist? Because he was outstanding in his field."
    ]
    joke = random.choice(jokes)
    bot.send_message(message.chat.id, f"Joke: {joke}")

# Handle any other command with a default response
@bot.message_handler(func=lambda message: True)
def handle_default(message):
    bot.reply_to(message, "I'm sorry, I don't understand that command. Type /help for instructions.")

# Start the bot
bot.polling()
